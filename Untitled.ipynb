# %%
import pandas as pd
import datetime
import numpy as np

# %%
df = pd.read_excel(r'/Users/vascobartolomeu/Desktop/Lista Incendios_2015.xlsx')
print(df.iloc[0,17])
print(str(int(df.iloc[0,17][8:10]) - int(df.iloc[0,15][8:10])) + 'days')
#df.head()
# Out:
#     Ano Codigo SGIF    Codigo_ANPC          Tipo          Distrito  \
# 0  2015    DM315252  2015160007544     Florestal  Viana do Castelo
# 1  2015    DM215305  2015130043758     Florestal             Porto
# 2  2015    DM415293  2015030021973     Florestal             Braga
# 3  2015    DM315261  2015160007563  Falso Alarme  Viana do Castelo
# 4  2015    BL115321  2015180015874      Agrícola             Viseu
#
#              Concelho           Freguesia                            Local  \
# 0       Ponte de Lima           Serdedelo      VALE DE TROVELA (SERDEDELO)
# 1  Marco de Canaveses  Vila Boa de Quires                    LUGAR DO FOFO
# 2          Vila Verde                Lage            RUA PROF ABEL MADEIRA
# 3       Ponte de Lima            Boalhosa  J. DEPOSITOS DE AGUA (BOALHOSA)
# 4        Castro Daire        Castro Daire      Farejinhas - Bº das Queirós
#
#       INE       x  ...  Falso Alarme Fogacho Incendio Agricola Perimetro  APS  \
# 0  160746  167814  ...             0       0        1        0       NaN  NaN
# 1  130731  193731  ...             0       0        1        0       NaN  NaN
# 2   31323  172162  ...             0       1        0        0       NaN  NaN
# 3  160709  171291  ...             1       0        0        0       NaN  NaN
# 4  180304  217299  ...             0       1        0        0       NaN  NaN
#
#    Causa     TipoCausa          Região PROF          UGF
# 0  122.0    Negligente  Entre Douro e Minho   Alto Minho
# 1  122.0    Negligente  Entre Douro e Minho       Tâmega
# 2   60.0  Desconhecida  Entre Douro e Minho  Baixo Minho
# 3  630.0  Desconhecida  Entre Douro e Minho   Alto Minho
# 4  630.0  Desconhecida        Beira Litoral   Dão Lafões
#
# [5 rows x 38 columns]

# %%
df.iloc[:,13:19]
# Out:
#                     DataAlerta HoraAlerta             DataExtincao  \
# 0      2015-03-24 00:00:00.000   17:01:00  2015-03-24 00:00:00.000
# 1      2015-03-24 00:00:00.000   17:10:00  2015-03-24 00:00:00.000
# 2      2015-03-24 00:00:00.000   19:15:00  2015-03-24 00:00:00.000
# 3      2015-03-24 00:00:00.000   20:05:00  2015-03-24 00:00:00.000
# 4      2015-03-24 00:00:00.000   20:10:00  2015-03-24 00:00:00.000
# ...                        ...        ...                      ...
# 23170  2015-08-09 00:00:00.000   02:10:00  2015-08-09 00:00:00.000
# 23171  2015-08-09 00:00:00.000   04:40:00  2015-08-09 00:00:00.000
# 23172  2015-08-09 00:00:00.000   05:50:00  2015-08-09 00:00:00.000
# 23173  2015-08-09 00:00:00.000   08:20:00  2015-08-09 00:00:00.000
# 23174  2015-08-09 00:00:00.000   09:09:00  2015-08-09 00:00:00.000
#
#       HoraExtincao         Data1Intervencao Hora1Intervencao
# 0         18:09:00  2015-03-24 00:00:00.000         17:10:00
# 1         18:47:00  2015-03-24 00:00:00.000         17:16:00
# 2         20:00:00  2015-03-24 00:00:00.000         19:25:00
# 3         21:30:00  2015-03-24 00:00:00.000         20:20:00
# 4         21:00:00  2015-03-24 00:00:00.000         20:15:00
# ...            ...                      ...              ...
# 23170     03:15:00  2015-08-09 00:00:00.000         02:20:00
# 23171     09:30:00  2015-08-09 00:00:00.000         04:53:00
# 23172     06:40:00  2015-08-09 00:00:00.000         05:55:00
# 23173     10:40:00  2015-08-09 00:00:00.000         08:25:00
# 23174     11:03:00  2015-08-09 00:00:00.000         09:12:00
#
# [23175 rows x 6 columns]

# %%
#print('0' + 'days', str(df.iloc[0,16].hour - df.iloc[0,14].hour) + 'h ' + str(df.iloc[0,16].minute - df.iloc[0,14].minute) + 'm ' + str(df.iloc[0,16].second - df.iloc[0,14].second) + 's')
print(df.iloc[0,17])
print(str(int(df.iloc[0,17][8:10]) - int(df.iloc[0,15][8:10])) + 'days')
# Out:
# 2015-03-24 00:00:00.000
# 0days

# %%
tempo_intervencao = np.zeros((10,), dtype=int)
tempo_extincao = np.zeros((10,), dtype=int)
x = datetime.datetime.strptime(df.iloc[0,15][0:19], '%y-%m-%d %H:%M:%S')
#tempo_extincao[0] = str(int(df.iloc[i,15][8:10]) - int(df.iloc[i,17][8:10])) + 'days', str(df.iloc[i,18].hour - df.iloc[i,16].hour) + 'h ' + str(df.iloc[i,18].minute - df.iloc[i,16].minute) + 'm ' + str(df.iloc[i,18].second - df.iloc[i,16].second) + 's'

print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 tempo_intervencao = np.zeros((10,), dtype=int)
#       2 tempo_extincao = np.zeros((10,), dtype=int)
# ----> 3 x = datetime.datetime.strptime(df.iloc[0,15][0:19], '%y-%m-%d %H:%M:%S')
#       4 #tempo_extincao[0] = str(int(df.iloc[i,15][8:10]) - int(df.iloc[i,17][8:10])) + 'days', str(df.iloc[i,18].hour - df.iloc[i,16].hour) + 'h ' + str(df.iloc[i,18].minute - df.iloc[i,16].minute) + 'm ' + str(df.iloc[i,18].second - df.iloc[i,16].second) + 's'
#       6 print(x)
#
# File /opt/homebrew/anaconda3/lib/python3.9/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File /opt/homebrew/anaconda3/lib/python3.9/_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2015-03-24 00:00:00' does not match format '%y-%m-%d %H:%M:%S'

# %%
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 76

# %%
import datetime
first_time = datetime.datetime.now()
first_time
# Out:
# datetime.datetime(2022, 10, 1, 12, 39, 51, 822936)
